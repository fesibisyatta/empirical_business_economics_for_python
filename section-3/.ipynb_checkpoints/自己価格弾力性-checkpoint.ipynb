# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from linearmodels.iv import IV2SLS

import matplotlib.pyplot as plt
import japanize_matplotlib
plt.style.use("ggplot")

# %%
data = pd.read_csv("output/processed_data.csv")

# OLSの推定
X = data[["price", "hppw", "FuelEfficiency", "size"]]
X = sm.add_constant(X)
y = data["logit_share"]
model = sm.OLS(y, X).fit(cov_type="HC1")

# BLP操作変数を用いたIV推定
formula = """
logit_share ~ 1 + hppw + FuelEfficiency + size
+ [price ~ iv_BLP_own_hppw
        + iv_BLP_own_FuelEfficiency
        + iv_BLP_own_size
        + iv_BLP_other_hppw
        + iv_BLP_other_FuelEfficiency
        + iv_BLP_other_size]
"""

iv_BLP = IV2SLS.from_formula(
    formula,
    data=data
).fit(cov_type="robust")


# 差別化操作変数を用いたIV推定
formula = """
logit_share ~ 1 + hppw + FuelEfficiency + size
+ [price ~ iv_GH_own_hppw
        + iv_GH_own_FuelEfficiency
        + iv_GH_own_size
        + iv_GH_other_hppw
        + iv_GH_other_FuelEfficiency
        + iv_GH_other_size]
"""

iv_GH = IV2SLS.from_formula(
    formula,
    data=data
).fit(cov_type="heteroskedastic")

# %%
list_wtp = []
for m in [model, iv_BLP, iv_GH]:
    list_wtp.append(
        [
            abs(m.params["hppw"]/ m.params["price"]),
            abs(m.params["size"]/ m.params["price"]),
            abs(m.params["FuelEfficiency"]/ m.params["price"])
        ]
    )

# %%
print("各変数の支払意思額の推定値")
pd.DataFrame(
    list_wtp, 
    columns=["hppw", "size", "FuelEfficiency"],
    index=["model", "iv_BLP", "iv_GH"]
)
# Out:
# 各変数の支払意思額の推定値
#              hppw      size  FuelEfficiency
# model    2.564524  0.714280        0.510087
# iv_BLP   0.751101  0.661032        0.457936
# iv_GH   15.260222  0.428019        0.229722

# %%
#v 自己価格弾力性
df_elas = pd.DataFrame()
df_elas["own_price_elasticity_ols"] = model.params["price"] * data["price"] * (1 - data["share"])
df_elas["own_price_elasticity_blp"] = iv_BLP.params["price"] * data["price"] * (1 - data["share"])
df_elas["own_price_elasticity_gh"] = iv_GH.params["price"] * data["price"] * (1 - data["share"])

# %%
# 表3.3の再現
df_elas.describe().T[["mean", "std", "min", "25%", "50%", "75%","max"]].round(2)
# Out:
#                           mean   std   min   25%   50%   75%   max
# own_price_elasticity_ols -0.65  0.47 -3.22 -0.73 -0.52 -0.36 -0.18
# own_price_elasticity_blp -0.72  0.52 -3.58 -0.81 -0.58 -0.40 -0.20
# own_price_elasticity_gh  -1.40  1.01 -6.97 -1.58 -1.13 -0.78 -0.39

# %%
pricevec = np.arange(0.3, 5.0 + 0.05, 0.05)
salecvec = []
revenuevec = []

# model_obj = model
model_obj = iv_GH

for price in pricevec:
    

    # 平均効用
    delta = (
        model_obj.params["hppw"] * data["hppw"] + model_obj.params["FuelEfficiency"] * data["FuelEfficiency"] 
        + model_obj.params["size"] * data["size"] + model_obj.params["price"] * price
        )

    if "const" in model_obj.params.index:
        delta += model_obj.params["const"]
    elif "Intercept" in model_obj.params.index:
        delta += model_obj.params["Intercept"]
    else:
        pass
    
    denom = 1 + sum(np.exp(delta))
    pred_sales = (np.exp(delta) / denom) * data["HH"]
    data["pred_sales"] = pred_sales

    pred_sale_for_ID = data[data["NameID"] == 87]["pred_sales"].values[0]

    salecvec.append(pred_sale_for_ID)
    revenuevec.append(price * pred_sale_for_ID)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(salecvec, pricevec, color="blue", label="販売台数")
plt.xlabel("販売台数 (台)")
plt.ylabel("価格 (百万円)")
plt.title("価格と販売台数の関係")

plt.subplot(1, 2, 2)
plt.plot(pricevec, revenuevec, color="orange", label="売上高")
plt.xlabel("価格 (百万円)")
plt.ylabel("収入 (億円)")
plt.title("価格と売上高の関係")

plt.tight_layout()
plt.show()

# %%
pricevec = np.arange(0.3, 5.0 + 0.05, 0.05)
salecvec = []
revenuevec = []

# model_obj = model
model_obj = iv_BLP

for price in pricevec:
    
    # アルファードの価格を変更
    temp_price = price

    # 平均効用
    delta = (
        model_obj.params["hppw"] * data["hppw"] + model_obj.params["FuelEfficiency"] * data["FuelEfficiency"] 
        + model_obj.params["size"] * data["size"] + model_obj.params["price"] * temp_price
        )

    if "const" in model_obj.params.index:
        delta += model_obj.params["const"]
    elif "Intercept" in model_obj.params.index:
        delta += model_obj.params["Intercept"]
    else:
        pass
    
    denom = 1 + sum(np.exp(delta))
    pred_sales = (np.exp(delta) / denom) * data["HH"]
    data["pred_sales"] = pred_sales

    pred_sale_for_ID = data[data["NameID"] == 87]["pred_sales"].values[0]

    salecvec.append(pred_sale_for_ID)
    revenuevec.append(price * pred_sale_for_ID)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(salecvec, pricevec, color="blue", label="販売台数")
plt.xlabel("販売台数 (台)")
plt.ylabel("価格 (百万円)")
plt.title("価格と販売台数の関係")

plt.subplot(1, 2, 2)
plt.plot(pricevec, revenuevec, color="orange", label="売上高")
plt.xlabel("価格 (百万円)")
plt.ylabel("収入 (億円)")
plt.title("価格と売上高の関係")

plt.tight_layout()
plt.show()
